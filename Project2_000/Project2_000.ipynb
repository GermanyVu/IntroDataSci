# %% [markdown]
# ## Project 2:
#
#
#
#
# ### Puzzle 1: Import pandas + read_csv
#
# The `graybook-cleaned.csv` is provided for you in the same directory as this notebook.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv("happinessdata.csv")

print(df)
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.168690        0.450662
# 1     Afghanistan  2009     4.401778            7.333790        0.552308
# 2     Afghanistan  2010     4.758381            7.386629        0.539075
# 3     Afghanistan  2011     3.831719            7.415019        0.521104
# 4     Afghanistan  2012     3.782938            7.517126        0.520637
# 5     Afghanistan  2013     3.572100            7.522238        0.483552
# 6     Afghanistan  2014     3.130896            7.516955        0.525568
# 7     Afghanistan  2015     3.982855            7.500539        0.528597
# 8     Afghanistan  2016     4.220169            7.497038        0.559072
# 9     Afghanistan  2017     2.661718            7.497755        0.490880
# 10    Afghanistan  2018     2.694303            7.494588        0.507516
# 11        Albania  2007     4.634252            9.077331        0.821372
# ...

# %% [markdown]
# ### Puzzle 2: Bar Charts
#
# Create two visualizations, one using `pandas` (`df.[...]`), one using `seaborn`, showing a bar chart displaying the number of faculty with **ONLY** the following academic titles:
#
# - `PROF`
# - `ASSOC PROF`
# - `ASST PROF`
#
# #### Using a pandas DataFrame:
#
# API: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html

# %%
df['Log GDP per capita'] = df['Log GDP per capita'].fillna(0)
gdp = np.array(df['Log GDP per capita'])
print(gdp.max())

df['Healthy life expectancy at birth'] = df['Healthy life expectancy at birth'].fillna(0)
lifeex = np.array(df['Healthy life expectancy at birth'])
print(lifeex.max())

df['Generosity'] = df['Generosity'].fillna(0)
lifeex = np.array(df['Generosity'])
print(lifeex.max())
print(lifeex.min())
print(lifeex.mean())
# Out:
# 11.77027607
# 76.80000305
# 0.6777426
# -0.336384535
# 7.485069630281646e-05

# %% [markdown]
# #### Using seaborn:
#
# API: https://seaborn.pydata.org/generated/seaborn.barplot.html
#
# *Remember: You can use a DataFrame as the `data` parameter!*

# %% [markdown]
# ### Puzzle 3: Histograms
#
# Create two visualizations, one using `pandas`, one using `seaborn`, showing the salary of **ALL** employees at The University of Illinois.
#
# #### Using a pandas DataFrame:

# %%
df = df.sort_values(by=["Salary"])
employee_name = df["Employee Name"].index.tolist()
employee_salary = df["Salary"].tolist()
#print(df)

plt.scatter(employee_name,employee_salary, color="blue", alpha=0.5)
dfplot = pd.DataFrame({"Salary":employee_salary})

plt.show()
#df_copy = df.copy()

#ax1 = dfplot.plot.scatter(x="Number",  y="Salary"  , c="DarkBlue")


hist = dfplot.hist(bins="auto")
#ax = dfbar_part3.plot.bar(x="Name", y="Salary", rot=0)

# %% [markdown]
# #### Using seaborn:

# %%
#sns.set(style="whitegrid")
#ax = sns.scatterplot(x="Number", y="Salary", data=dfplot)

sns.set(color_codes=True)
sns.set(style="whitegrid", palette="muted")
ax = sns.distplot(df["Salary"].astype(float))

# %% [markdown]
# ### Puzzle 4: Box Plots
#
# Create two visualizations, one using `pandas`, one using `seaborn`, showing the salary of academic employees, by academic title, **within the College of Engineering**.
#
# #### Using a pandas DataFrame:

# %%
df = df.fillna("No_Title")
dfsubset1_part4 = df[df["Primary College"].isin(["Engineering" ]) ]
dfsubset2_part4 = dfsubset1_part4.groupby("Academic Title").count()
print(dfsubset2_part4)

employee_salary = df["Salary"].tolist()

#count = dfsubset2_part4["Index"].tolist()
#print(dfsubset1_part4.set_index("Academic Title").T)
#dfbox = pd.DataFrame({"Academic Title":["PROF", "ASSOC PROF","ASST PROF" ], "Count":count})
#print(dfsubset1_part4)

dfsubset1_part4.boxplot(by ="Academic Title", column =["Salary"], figsize=(50,50),grid = False) 

#boxplot = dfsubset1_part4.boxplot(column=["Salary"])
# Out:
#                      Index  Employee Name  Primary Job Title  Primary College  \
# Academic Title
# ADJ ASST PROF            2              2                  2                2
# ADJ LECTURER             1              1                  1                1
# ASSOC PROF              69             69                 69               69
# ASST PROF              120            120                120              120
# CLIN ASST PROF           1              1                  1                1
# CLIN PROF                1              1                  1                1
# INSTRUCTOR               1              1                  1                1
# LECTURER                17             17                 17               17
# No_Title               329            329                329              329
# PROF                   230            230                230              230
# RES ASSOC PROF           2              2                  2                2
# ...

# %% [markdown]
# #### Using seaborn:
